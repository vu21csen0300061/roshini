# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **D.Harshita**
# Currently I am a computer science student

# %% [markdown]
# *I am interested in Data Science because we can learn how to utilise and manipulate data to analyse and solve real life problems, which is challenging.*

# %% [markdown]
# ### My code below is a simple calculation - product of two numbers

# %%
x=7
y=5
print(x*y)
# Out:
# 35

# %% [markdown]
# ***
# - Artificial Intelligence
# - Data science
#
# 1. Cyber security
# 2. Internet of things
